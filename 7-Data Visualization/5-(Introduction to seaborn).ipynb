# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from cycler import cycler
import seaborn as sns

# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
sns.relplot(
    data=tips
)

# %%
sns.set_theme()
tips = sns.load_dataset('tips')
sns.relplot(
    data=tips
)

# %%
sns.set_theme()
tips = sns.load_dataset('tips')
sns.relplot(
    data=tips,
    x='total_bill', y='tip', col='time',
    hue='smoker', style='smoker', size='size'
)

# %%
tips.smoker.value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.set_theme(style='whitegrid', font_scale=1.5)
tips = sns.load_dataset('tips')
sns.relplot(
    data=tips,
    x='total_bill', y='tip', col='time',
    hue='smoker', style='smoker', size='size'
)

# %%
sns.set_theme()
tips = sns.load_dataset('tips')
sns.relplot(
    data=tips,
    kind='line',
    x='total_bill', y='tip', col='time',
    hue='smoker', style='smoker', size='size'
)

# %%
dots = sns.load_dataset('dots')

sns.set_theme()
tips = sns.load_dataset('tips')
sns.relplot(
    data=dots,
    kind='line',
    x='time', y='firing_rate'
)

# %%
dots = sns.load_dataset('dots')

sns.set_theme()
tips = sns.load_dataset('tips')
sns.relplot(
    data=dots,
    kind='line',
    x='time', y='firing_rate',
    col='align',
    hue='choice',
    size='coherence'
)

# %%
dots = sns.load_dataset('dots')

sns.set_theme()
tips = sns.load_dataset('tips')
sns.relplot(
    data=dots,
    kind='line',
    x='time', y='firing_rate',
    col='align',
    hue='choice',
    size='coherence',
    style='choice'
)

# %%
dots = sns.load_dataset('dots')

sns.set_theme()
tips = sns.load_dataset('tips')
sns.relplot(
    data=dots,
    kind='line',
    x='time', y='firing_rate',
    col='align',
    hue='choice',
    size='coherence',
    facet_kws=dict(sharex=False)
)

# %%
fmri = sns.load_dataset('fmri')
sns.relplot(
    data=fmri,
    kind='line',
    x='timepoint', y='signal',
    col='region',
    hue='event',
    size='event'
)

# %%
# lmplot # linear model plot

# %%
sns.lmplot(
    data=tips,
    x='total_bill', y='tip',
    col='time',
    hue='smoker'
)

# %%
sns.displot(data=tips, x='total_bill')

# %%
sns.displot(data=tips, x='total_bill', col='time')

# %%
sns.displot(data=tips, x='total_bill', col='time',
    kde=True # kernel destiny estimation
)

# %%
sns.displot(data=tips, x='total_bill', col='time',
    rug=True,
    kind='ecdf'
)

# %%
sns.catplot(
    data=tips
)

# %%
sns.catplot(
    data=tips,
    kind='swarm',
)
# Out:
# d:\dev\venv\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 50.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\dev\venv\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 68.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\dev\venv\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 60.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\dev\venv\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 76.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(
    data=tips,
    kind='swarm',
    x='day', y='total_bill'
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill'
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
    hue='smoker',
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
    hue='smoker', split=True,
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='bar',
    hue='smoker'
)

# %%
penguins = sns.load_dataset('penguins')

# %%
sns.jointplot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_length_mm',
    hue='species',
)

# %%
sns.jointplot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_length_mm',
)

# %%
sns.pairplot(data=penguins)

# %%
sns.pairplot(data=penguins, hue='species')

# %%
g = sns.PairGrid(penguins, hue='species', corner=True)
g.map_lower(sns.kdeplot, hue=None, levels=5, color='.2')
g.map_lower(sns.scatterplot, marker='+')
g.map_diag(sns.histplot, element='step', linewidth=0, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))
