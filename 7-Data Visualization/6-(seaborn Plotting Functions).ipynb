# %%
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
p=sns.load_dataset('penguins')
sns.histplot(
    data=p,
    x='flipper_length_mm',
    
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
p=sns.load_dataset('penguins')
sns.histplot(
    data=p,
    x='flipper_length_mm',
 hue='species'   
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
p=sns.load_dataset('penguins')
sns.histplot(
    data=p,
    x='flipper_length_mm',
 hue='species'   ,
 multiple='stack'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
p=sns.load_dataset('penguins')
sns.histplot(
    data=p,
    x='flipper_length_mm',
 hue='species'   ,
 multiple='fill'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.kdeplot(
    data=p,
    x='flipper_length_mm',
 hue='species'   ,
 multiple='fill'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.kdeplot(
    data=p,
    x='flipper_length_mm',
 hue='species'   ,
 multiple='stack'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.kdeplot(
    data=p,
    x='flipper_length_mm',
 hue='species'   ,
 multiple='layer'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.set_style('darkgrid')
sns.kdeplot(
    data=p,
    x='flipper_length_mm',
 hue='species'   ,
 multiple='stack'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.set_style('whitegrid')
sns.kdeplot(
    data=p,
    x='flipper_length_mm',
 hue='species'   ,
 multiple='stack'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.histplot( # axis level
    data=p,
    x='flipper_length_mm',
    hue='species'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.displot( # figure level
    data=p,
    x='flipper_length_mm',
    hue='species'
)

# %%
sns.displot( # figure level
    data=p,
    x='flipper_length_mm',
    hue='species',
    col='species'
)

# %%
f, axs = plt.subplots(
    1, 2,
    figsize=(10, 5),
    layout='constrained',
    gridspec_kw={'width_ratios': (6, 2)}
)

# %%
sns.scatterplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
f, axs = plt.subplots(
    1, 2,
    figsize=(10, 5),
    layout='constrained',
    gridspec_kw={'width_ratios': (6, 2)}
)

sns.scatterplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species',
    ax=axs[0]
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
f, axs = plt.subplots(
    1, 2,
    figsize=(10, 5),
    layout='constrained',
    gridspec_kw={'width_ratios': (6, 2)}
)

sns.scatterplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species',
    ax=axs[1]
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
f, axs = plt.subplots(
    1, 2,
    figsize=(10, 5),
    layout='constrained',
    gridspec_kw={'width_ratios': (6, 2)}
)

sns.scatterplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species',
    ax=axs[0]
)

sns.histplot(
    data=p,
    x='species',
    hue='species',
    ax=axs[1]
)
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %%
sns.histplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species',
    alpha=1
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
sns.histplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species',
    alpha=0
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
sns.histplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species',
    alpha=0.5
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
sns.histplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species',
    alpha=0.5,
    shrink=1
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
sns.histplot(
    data=p,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species',
    alpha=0.5,
    shrink=0
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
sns.histplot(
    data=p,
    x='species',
    hue='species',
    alpha=0.5,
    shrink=0.2
)
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %%
sns.histplot(
    data=p,
    x='species',
    hue='species',
    alpha=0.5,
    shrink=1
)
# Out:
# <Axes: xlabel='species', ylabel='Count'>

# %%
tips = sns.load_dataset('tips')
sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
)

# %%
g = sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
)

g.ax.plot(np.random.rand(50))

# %%
g = sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
)

g.ax.plot(np.random.rand(50))

g.ax.axline(xy1=(5, 1), xy2=(35, 6))

# %%
g = sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
)

g.ax.plot(np.random.rand(50))

g.ax.axline(xy1=(5, 1), slope=0.5, color='r')

# %%
g = sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
)

g.set_axis_labels(
    'A',   'B'
)

# %%
penguins = sns.load_dataset('penguins')

sns.displot(
    data=penguins
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='hist'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='kde'
)

# %%
f, ax = plt.subplots(1,2, sharey=True)

# %%
f, ax = plt.subplots(1,2, sharex=True, sharey=True)

# %%
g = sns.FacetGrid(p)

# %%
g = sns.FacetGrid(p, col='sex')

# %%
g = sns.FacetGrid(p, col='sex', height=3, aspect=.5)

# %%
g = sns.FacetGrid(p, col='species', height=3, aspect=.5)

# %%
sns.jointplot(
    data=penguins,
    x='flipper_length_mm', y='bill_length_mm',
)

# %%
sns.jointplot(
    data=penguins,
    x='flipper_length_mm', y='bill_length_mm',
    hue='species'
)

# %%
# sns.
#     displot
#     relpot
#     catplot
# three main
