# %%
import seaborn as sns

# %matplotlib inline

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.distplot
# Out:
# <function seaborn.distributions.distplot(a=None, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None, x=None)>

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    binwidth=10
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    binwidth=1
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    bins=10
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    bins=100
)

# %%
tips = sns.load_dataset('tips')

# %%
tips.size
# Out:
# 1708

# %%
tips.size.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Amir\Desktop\Pytopia ML 2022\00-Practices\7-Data Visualization\8-(Visualizing Distribution of Data with displot).ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Amir/Desktop/Pytopia%20ML%202022/00-Practices/7-Data%20Visualization/8-%28Visualizing%20Distribution%20of%20Data%20with%20displot%29.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> tips.size.value_counts()
#
# AttributeError: 'int' object has no attribute 'value_counts'

# %%
tips['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.displot(
    data=tips,
    x='size'
)

# %%
sns.displot(
    data=tips,
    x='size',
    binwidth=1
)

# %%
sns.displot(
    data=tips,
    x='size',
    bins=[0,5,6,9]
)

# %%
sns.displot(
    data=tips,
    x='size',
    discrete=True
)

# %%
sns.displot(
    data=tips,
    x='day',
    
)

# %%
sns.displot(
    data=tips,
    x='day',
    shrink=0.8
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    multiple='stack'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='step' # bars, step, poly
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='bars' # bars, step, poly
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='poly' # bars, step, poly
)

# %%
g = sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='step' # bars, step, poly
)

g.map(
    sns.histplot,
    data=penguins,
    x='flipper_length_mm',
)

# %%
g = sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='poly' # bars, step, poly
)

g.map(
    sns.histplot,
    data=penguins,
    x='flipper_length_mm',
)

# %%
g = sns.displot(
    data=penguins,
    x='flipper_length_mm',
    element='poly' # bars, step, poly
)

g.map(
    sns.histplot,
    data=penguins,
    x='flipper_length_mm',
)

# %%
g = sns.displot(
    data=penguins,
    x='flipper_length_mm',
    element='poly' # bars, step, poly
)

g.map(
    sns.histplot,
    data=penguins,
    x='flipper_length_mm',
    element='step',
    color='red',
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='step', # bars, step, poly
    multiple='stack', # layer, dodge, stack, fill
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='step', # bars, step, poly
    multiple='layer', # layer, dodge, stack, fill
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='step', # bars, step, poly
    multiple='dodge', # layer, dodge, stack, fill
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='step', # bars, step, poly
    multiple='fill', # layer, dodge, stack, fill
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    multiple='dodge',
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    col='sex'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    stat='percent'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    stat='count'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    stat='frequency'
)

# %%
    sns.displot(
    data=penguins,
    x='flipper_length_mm',
    stat='probability'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    stat='density'
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='kde'
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='hist'
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='ecdf'
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='ecdf'# ['hist', 'kde', 'ecdf']
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='kde',
    bw_adjust=0.25
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='kde',
    bw_adjust=2
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='kde',
    hue='species'
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='kde',
    hue='species',
    multiple='stack'
)

# %%
# kernel density estimation
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    kind='kde',
    hue='species',
    fill=True
)

# %%
sns.displot(
    tips,
    x='total_bill',
    kind='kde'
)

# %%
sns.displot(
    tips,
    x='total_bill',
    kind='kde',
    cut=0
)

# %%
diamonds = sns.load_dataset('diamonds')
sns.displot(
    diamonds,
    x='carat',
    kind='kde'
)

# %%
sns.displot(
    diamonds,
    x='carat',
)

# %%
sns.displot(
    diamonds,
    x='carat',
    kind='kde',
    rug=True,
)

# %%
# Empirical cumulative distribution

# %%
sns.displot(
    diamonds,
    x='carat',
    kind='ecdf',
)

# %%
sns.displot(
    penguins,
    x='flipper_length_mm',
    kind='ecdf',
)

# %%
sns.displot(
    penguins,
    x='flipper_length_mm',
    kind='ecdf',
    hue='species',
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
    cbar=True
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
    kind='hist'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
    kind='kde'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
    kind='hist',
    hue='species'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
    kind='hist',
    hue='species',
    binwidth=(2, 0.5)
)

# %%
sns.displot(
    data=diamonds,
    x='price',
    y='clarity',
    kind='hist'
)

# %%
sns.displot(
    data=diamonds,
    x='price',
    y='clarity',
    kind='hist',
    log_scale=(True, False)
)

# %%
sns.displot(
    data=diamonds,
    x='color',
    y='clarity',
)

# %%
# Distribution visualization in other settings

# %%
sns.relplot

sns.scatterplot
sns.lineplot

sns.displot

sns.histplot
sns.kdeplot
sns.rugplot
sns.ecdfplot
# Out:
# <function seaborn.distributions.ecdfplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='proportion', complementary=False, palette=None, hue_order=None, hue_norm=None, log_scale=None, legend=True, ax=None, **kwargs)>

# %%
sns.jointplot
sns.pairplot
# Out:
# <function seaborn.axisgrid.pairplot(data, *, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)>

# %%
sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm'
)

# %%
sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='hist'
)

# %%
sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde'
)

# %%
sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='hex'
)

# %%
g = sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='hex'
)

g.plot_joint
g.plot_marginals
# Out:
# <bound method JointGrid.plot_marginals of <seaborn.axisgrid.JointGrid object at 0x000001F9BFAE1150>>

# %%
g = sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde',
    hue='species'
)

g.plot_joint
g.plot_marginals
# Out:
# <bound method JointGrid.plot_marginals of <seaborn.axisgrid.JointGrid object at 0x000001F9C0749590>>

# %%
g = sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde',
    hue='species',
    fill=True,
)

g.plot_joint
g.plot_marginals
# Out:
# <bound method JointGrid.plot_marginals of <seaborn.axisgrid.JointGrid object at 0x000001F9C09E2BD0>>

# %%
g = sns.JointGrid(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
)

# %%
g = sns.JointGrid(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
)

g.plot_joint(
    sns.histplot
)

# %%
g = sns.JointGrid(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
)

g.plot_joint(
    sns.histplot
)

g.plot_marginals(
    sns.boxplot
)

# %%
g = sns.JointGrid(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
)

g.plot_joint(
    sns.histplot
)

g.plot_marginals(
    sns.kdeplot
)

# %%
g = sns.JointGrid(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
)

g.plot_joint(
    sns.histplot
)

g.plot_marginals(
    sns.ecdfplot
)

# %%
g = sns.JointGrid(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
)

g.plot_joint(
    sns.kdeplot, rug=True
)

g.plot_marginals(
    sns.boxplot
)
# Out:
# d:\dev\venv\Lib\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'rug'
#   cset = contour_func(

# %%
sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde',
    fill=True,
    hue='species'
)

# %%
sns.jointplot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde',
    fill=True,
    hue='species',
    rug=True
)
# Out:
# d:\dev\venv\Lib\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'rug'
#   cset = contour_func(

# %%
sns.displot(
    data=penguins,
    x='bill_length_mm',
    y='bill_depth_mm',
    kind='kde',
    rug=True,
)

# %%
sns.pairplot(penguins)

# %%
g = sns.PairGrid(penguins)

# g.map_upper(sns.histplot)
# g.map_lower(sns.dkeplot, fill=True)
# g.diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)

g.map_upper(sns.histplot)
# g.map_lower(sns.dkeplot, fill=True)
# g.diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)

# g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
# g.diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)

g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
# g.diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)

g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
g = sns.PairGrid(penguins)

g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
