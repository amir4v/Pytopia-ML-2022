# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# %matplotlib inline

# %%
img = mpimg.imread('./img.jpg')

# %%
img.shape
# Out:
# (187, 269, 3)

# %%
img
# Out:
# array([[[ 57, 104, 194],
#         [ 57, 104, 194],
#         [ 57, 104, 194],
#         ...,
#         [ 40,  88, 173],
#         [ 40,  88, 173],
#         [ 40,  88, 173]],
#
#        [[ 57, 104, 194],
#         [ 57, 104, 194],
#         [ 57, 104, 194],
#         ...,
#         [ 40,  88, 173],
#         [ 40,  88, 173],
#         [ 40,  88, 173]],
#
#        [[ 57, 104, 194],
#         [ 57, 104, 194],
#         [ 57, 104, 194],
#         ...,
#         [ 40,  88, 173],
#         [ 40,  88, 173],
#         [ 40,  88, 173]],
#
#        ...,
#
#        [[ 48,  95, 185],
#         [ 48,  95, 185],
#         [ 47,  94, 184],
#         ...,
#         [ 38,  84, 169],
#         [ 38,  84, 169],
#         [ 38,  84, 169]],
#
#        [[ 48,  95, 185],
#         [ 48,  95, 185],
#         [ 47,  94, 184],
#         ...,
#         [ 38,  84, 169],
#         [ 38,  84, 169],
#         [ 38,  84, 169]],
#
#        [[ 48,  95, 185],
#         [ 48,  95, 185],
#         [ 47,  94, 184],
#         ...,
#         [ 38,  84, 169],
#         [ 38,  84, 169],
#         [ 38,  84, 169]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
imgplot = plt.imshow(img)

# %%
plt.imshow(img[::] + 100)

# %%
plt.imshow(img[::] + -50)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig, ax = plt.subplots(figsize=(3,1))
plt.imshow(img)

# %%
fig, axs = plt.subplots(2,2, figsize=(8,4))
axs[0][1].imshow(img)

# %%
plt.imshow(img[:, :, 2] + 200)

# %%
plt.imshow(img[:,:,2], cmap='gray')

# %%
plt.imshow(img[:,:,0], cmap='gray')

# %%
plt.imshow(img[:,:,0], cmap='hot')

# %%
plt.imshow(img[:,:,0], cmap='hot')
plt.colorbar()

# %%
from PIL import Image

# %%
img = Image.open('./img.jpg')
img.thumbnail((100, 100))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x70>

# %%
imgplt = plt.imshow(img, interpolation='nearest')

# %%
imgplt = plt.imshow(img)

# %%
imgplt = plt.imshow(img, interpolation='bicubic')
