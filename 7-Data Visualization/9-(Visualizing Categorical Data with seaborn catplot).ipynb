# %%
import seaborn as sns

# %matplotlib inline

# %%
sns.catplot

# categorical scatterplots
sns.stripplot
sns.swarmplot

# categorical distribution plots
sns.boxplot
sns.violinplot
sns.boxenplot

# categorical estimate plots
sns.pointplot
sns.barplot
sns.countplot
# Out:
# <function seaborn.categorical.countplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, fill=True, hue_norm=None, stat='count', width=0.8, dodge='auto', gap=0, log_scale=None, native_scale=False, formatter=None, legend='auto', ax=None, **kwargs)>

# %%
tips = sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill'
)

# %%
sns.relplot(
    data=tips,
    x='total_bill',
    y='tip'
)

# %%
sns.displot(
    data=tips,
    x='total_bill',
    y='tip'
)

# %%
sns.catplot(
    data=tips,
    x='total_bill',
    y='tip'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    jitter=False
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    jitter=0.1
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    jitter=0.1,
    kind='strip'
)

# %%
sns.stripplot(
    data=tips,
    x='day',
    y='tip',
    jitter=0.1,
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    kind='swarm'
)
# Out:
# d:\dev\venv\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    kind='swarm',
    hue='sex'
)
# Out:
# d:\dev\venv\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    kind='swarm',
    hue='sex',
    order=['Fri', 'Sat']
)

# %%
sns.catplot(
    data=tips,
    x='size',
    y='total_bill'
)

# %%
sns.catplot(
    data=tips[tips['size'] != 3],
    x='size',
    y='total_bill'
)

# %%
sns.catplot(
    data=tips[tips['size'] != 3],
    y='size',
    x='total_bill'
)

# %%
sns.catplot(
    data=tips[tips['size'] != 3],
    y='size',
    x='total_bill',
    kind='swarm'
)
# Out:
# d:\dev\venv\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\dev\venv\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(
    data=tips,
    y='day',
    x='total_bill',
    
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='box',
    hue='smoker'
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='swarm',
    hue='smoker'
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='box',
    hue='smoker',
    dodge=False
)

# %%
tips['weekend'] = tips.day.isin(['Sat', 'Sun'])

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  weekend
# 0         16.99  1.01  Female     No   Sun  Dinner     2     True
# 1         10.34  1.66    Male     No   Sun  Dinner     3     True
# 2         21.01  3.50    Male     No   Sun  Dinner     3     True
# 3         23.68  3.31    Male     No   Sun  Dinner     2     True
# 4         24.59  3.61  Female     No   Sun  Dinner     4     True
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     True
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     True
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     True
# 242       17.82  1.75    Male     No   Sat  Dinner     2     True
# 243       18.78  3.00  Female     No  Thur  Dinner     2    False
#
# [244 rows x 8 columns]

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='box'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='box',
    hue='weekend'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='box',
    hue='weekend',
    dodge=True
)

# %%
diamonds = sns.load_dataset('diamonds')

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='boxen', # boxen
    hue='weekend',
    dodge=False
)

# %%
sns.catplot(
    data=diamonds.sort_values('color'),
    x='color',
    y='price',
)

# %%
sns.catplot(
    data=diamonds.sort_values('color'),
    x='color',
    y='price',
    kind='box'
)

# %%
sns.catplot(
    data=diamonds.sort_values('color'),
    x='color',
    y='price',
    kind='boxen'
)

# %%
sns.catplot(
    data=diamonds.sort_values('color'),
    x='color',
    y='price',
    kind='boxen',
    hue='color'
)

# %%
sns.catplot(
    data=diamonds.sort_values('color'),
    x='color',
    y='price',
    kind='violin',
    hue='color'
)

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
    hue='weekend',
    dodge=False,
    bw=0.1
)
# Out:
# C:\Users\Amir\AppData\Local\Temp\ipykernel_14704\1213870170.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.1`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.catplot(

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
    hue='sex',
    dodge=False,
    bw=0.1
)
# Out:
# C:\Users\Amir\AppData\Local\Temp\ipykernel_14704\1723815394.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.1`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.catplot(

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
    hue='sex',
    split=True,
    bw=0.1
)
# Out:
# C:\Users\Amir\AppData\Local\Temp\ipykernel_14704\248728514.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.1`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.catplot(

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
    hue='sex',
    split=True,
    bw=0.1,
    inner='stick'
)
# Out:
# C:\Users\Amir\AppData\Local\Temp\ipykernel_14704\2915630443.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.1`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.catplot(

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
    hue='sex',
    split=True,
    bw=0.1,
    inner='stick',
    palette='pastel',
)
# Out:
# C:\Users\Amir\AppData\Local\Temp\ipykernel_14704\781233444.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.1`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.catplot(

# %%
sns.catplot(
    data=tips,
    x='day', y='total_bill',
    kind='violin',
    hue='sex',
    split=True,
    bw=0.1,
    inner='stick',
    palette='muted',
)
# Out:
# C:\Users\Amir\AppData\Local\Temp\ipykernel_14704\1587018516.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.1`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.catplot(

# %%
g = sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='violin',
    inner=None,
)

sns.swarmplot(
    data=tips,
    x='day',y='total_bill',
    color='k',
    size=3,
    ax=g.ax
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
g = sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='violin',
    inner=None,
)

sns.stripplot(
    data=tips,
    x='day',y='total_bill',
    color='k',
    size=3,
    ax=g.ax
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
g = sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='violin',
    inner=None,
)

sns.stripplot(
    data=tips,
    x='day',y='total_bill',
    color='k',
    size=3,
    ax=g.ax,
    jitter=0.1
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Estimate central tendency

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.catplot(
    data=titanic,
    x='sex',
    y='survived'
)

# %%
sns.catplot(
    data=titanic,
    x='sex',
    y='survived',
    hue='class'
)

# %%
sns.catplot(
    data=titanic,
    x='sex',
    y='survived',
    hue='class',
    kind='bar'
)

# %%
sns.catplot(
    data=titanic,
    x='sex',
    y='survived',
    hue='class',
    kind='bar',
    errorbar=None
)

# %%
sns.catplot(
    data=titanic,
    x='sex',
    y='survived',
    hue='class',
    kind='bar',
    errorbar='se'
)

# %%
sns.catplot(
    data=titanic,
    x='sex',
    hue='class',
    kind='bar',
)

# %%
sns.catplot(
    data=titanic,
    x='sex',
    hue='class',
    kind='count',
)

# %%
sns.catplot(
    data=titanic,
    x='sex',
    kind='count',
)

# %%
sns.pointplot(
    data=titanic,
    x='sex', y='survived',
)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.pointplot(
    data=titanic,
    x='sex', y='survived',
    hue='class'
)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.catplot(
    data=titanic,
    x='sex', y='survived',
    hue='class',
    kind='point'
)

# %%
sns.catplot(
    data=titanic,
    x='class', y='survived',
    hue='sex',
    kind='point',
    palette={'male': 'g', 'female': 'm'},
    markers=['^', 'o']
)

# %%
sns.catplot(
    data=titanic,
    x='class', y='survived',
    hue='sex',
    kind='point',
    palette={'male': 'g', 'female': 'm'},
    markers=['^', 'o'],
    linestyle=['-', '--']
)

# %%
sns.catplot(
    data=titanic,
    x='class', y='survived',
    hue='sex',
    kind='point',
    palette={'male': 'g', 'female': 'm'},
    markers=['^', 'o'],
    linestyle=['-', '--'],
    row='class'
)

# %%
sns.catplot(
    data=titanic,
    x='class', y='survived',
    hue='sex',
    kind='point',
    palette={'male': 'g', 'female': 'm'},
    markers=['^', 'o'],
    linestyle=['-', '--'],
    col='class'
)
